# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
sns.set()

# %% [markdown]
# # Считывание и первый взгляд на данные

# %% [markdown]
# https://www.kaggle.com/gregorut/videogamesales
#
# https://www.kaggle.com/ashaheedq/video-games-sales-2019

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Yorko/mlcourse.ai/master/data/video_games_sales.csv')

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
df.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %%
df.sample(5)
# Out:
#                                                     Name Platform  \
# 4718   James Patterson Women's Murder Club: Games of ...       DS
# 5088                                    Reel Fishing III      PS2
# 10763                                       Shadow Tower       PS
# 1010                                   Kirby's Adventure      NES
# 12673                      Syphon Filter: Logan's Shadow      PS2
#
#        Year_of_Release         Genre                    Publisher  NA_Sales  \
# 4718            2009.0     Adventure                          THQ      0.15
# 5088            2003.0        Sports                      Natsume      0.18
# 10763           1998.0  Role-Playing                From Software      0.01
# 1010            1993.0      Platform                     Nintendo      0.79
# 12673           2010.0       Shooter  Sony Computer Entertainment      0.03
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
df['Year_of_Release'] = df['Year_of_Release'].astype('Int32')

# %%
# Проверяем, есть ли пропущенные значения (NaN) в столбце 'Year_of_Release'
# Метод isna() возвращает булевый DataFrame, где True указывает на пропущенное значение
# Метод any() возвращает True, если хотя бы одно значение в столбце равно True (т.е. есть хотя бы одно пропущенное значение)
df['Year_of_Release'].isna().any()
# Out:
# True

# %%
df[df['Year_of_Release'].isna()]
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2             <NA>
# 377                     FIFA Soccer 2004      PS2             <NA>
# 456           LEGO Batman: The Videogame      Wii             <NA>
# 475           wwe Smackdown vs. Raw 2006      PS2             <NA>
# 609                       Space Invaders     2600             <NA>
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP             <NA>
# 16409                      Freaky Flyers       GC             <NA>
# 16452                          Inversion       PC             <NA>
# 16462        Hakuouki: Shinsengumi Kitan      PS3             <NA>
# 16526                       Virtua Quest       GC             <NA>
#
#               Genre                               Publisher  NA_Sales  \
# 183          Sports                         Electronic Arts      4.26
# ...

# %%
df['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
df['User_Score'] = df['User_Score'].replace('tbd', np.nan)

# %%
df['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
df['User_Score'] = df['User_Score'].astype('float')

# %%
df['User_Score'].dtype
# Out:
# dtype('float64')

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count          16450.0  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min             1980.0      0.000000      0.000000      0.000000
# 25%             2003.0      0.000000      0.000000      0.000000
# 50%             2007.0      0.080000      0.020000      0.000000
# 75%             2010.0      0.240000      0.110000      0.040000
# max             2020.0     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
df.describe(percentiles=[0.1, 0.9])
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count          16450.0  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min             1980.0      0.000000      0.000000      0.000000
# 10%             1999.0      0.000000      0.000000      0.000000
# 50%             2007.0      0.080000      0.020000      0.000000
# 90%             2014.0      0.610000      0.350000      0.170000
# max             2020.0     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
df.describe(include=['object'])
# Out:
#                                Name Platform   Genre        Publisher  \
# count                         16717    16719   16717            16665
# unique                        11562       31      12              581
# top     Need for Speed: Most Wanted      PS2  Action  Electronic Arts
# freq                             12     2161    3370             1356
#
#        Developer Rating
# count      10096   9950
# unique      1696      8
# top      Ubisoft      E
# freq         204   3991

# %%
df[df['Name'] == 'Need for Speed: Most Wanted'].sort_values('Year_of_Release')
# Out:
#                               Name Platform  Year_of_Release   Genre  \
# 253    Need for Speed: Most Wanted      PS2             2005  Racing
# 1591   Need for Speed: Most Wanted     X360             2005  Racing
# 1998   Need for Speed: Most Wanted       XB             2005  Racing
# 3581   Need for Speed: Most Wanted       GC             2005  Racing
# 5973   Need for Speed: Most Wanted       PC             2005  Racing
# 6411   Need for Speed: Most Wanted       DS             2005  Racing
# 6474   Need for Speed: Most Wanted      GBA             2005  Racing
# 523    Need for Speed: Most Wanted      PS3             2012  Racing
# 1190   Need for Speed: Most Wanted     X360             2012  Racing
# 2048   Need for Speed: Most Wanted      PSV             2012  Racing
# 11716  Need for Speed: Most Wanted       PC             2012  Racing
# 6274   Need for Speed: Most Wanted     WiiU             2013  Racing
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# # Визуальный анализ

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# * hist

# %%
df['NA_Sales'].plot.hist();
plt.show()

# %%
df['Critic_Score'].plot.hist();
plt.show()

# %%
plt.hist(df['Critic_Score'])
plt.show()

# %%
sns.histplot(df['Critic_Score'].dropna())
plt.show()

# %%
sns.kdeplot(df['Critic_Score'].dropna());
plt.show()

# %% [markdown]
# * bar

# %%
df['Platform'].value_counts().plot.bar();
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.show()
sns.barplot(y=df['Platform'].value_counts().values, x=df['Platform'].value_counts().index);

# %% [markdown]
# * scatterplot

# %%
sns.scatterplot(data=df, x='NA_Sales', y='Global_Sales');
plt.show()

# %%
sns.scatterplot(data=df, x='Year_of_Release', y='Global_Sales');
plt.show()

# %%
sns.scatterplot(data=df, x='Year_of_Release', y='Global_Sales', hue='Genre');
plt.show()

# %%
df['Sports'] = df['Genre'].apply(lambda x: 'Sports' if x == 'Sports' else 'Other')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
sns.scatterplot(data=df, x='Year_of_Release', y='Global_Sales', hue='Sports');
plt.show()

# %%
df[df['Global_Sales'] > 60]
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii             2006  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0      3.77         8.45         82.53          76.0          51.0
#
#    User_Score  User_Count Developer Rating  Sports
# 0         8.0       322.0  Nintendo      E  Sports

# %% [markdown]
# * jointplot

# %%
sns.jointplot(data=df, x='Year_of_Release', y='Global_Sales');
plt.show()

# %% [markdown]
# * корреляция

# %% [markdown]
# https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F

# %%
corr = df.select_dtypes(include=['number']).corr()

# %%
corr
# Out:
#                  Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year_of_Release         1.000000 -0.092562  0.003842 -0.168386     0.037700
# NA_Sales               -0.092562  1.000000  0.765336  0.449598     0.638654
# EU_Sales                0.003842  0.765336  1.000000  0.435068     0.722796
# JP_Sales               -0.168386  0.449598  0.435068  1.000000     0.291096
# Other_Sales             0.037700  0.638654  0.722796  0.291096     1.000000
# Global_Sales           -0.076433  0.941010  0.901239  0.612300     0.749242
# Critic_Score            0.011411  0.240755  0.220752  0.152593     0.198554
# Critic_Count            0.223407  0.295413  0.277533  0.180219     0.251639
# User_Score             -0.267851  0.086200  0.055337  0.125598     0.057119
# User_Count              0.175339  0.246429  0.283360  0.075638     0.238982
#
#                  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# ...

# %%
# Рисуем тепловую карту для корреляций
plt.figure(figsize=(15,8));
sns.heatmap(corr, annot=True, fmt='.3f');

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [False, False, False,  True,  True,  True,  True,  True,  True,
#          True],
#        [False, False, False, False,  True,  True,  True,  True,  True,
#          True],
#        [False, False, False, False, False,  True,  True,  True,  True,
#          True],
#        [False, False, False, False, False, False,  True,  True,  True,
#          True],
#        [False, False, False, False, False, False, False,  True,  True,
#          True],
#        [False, False, False, False, False, False, False, False,  True,
#          True],
#        [False, False, False, False, False, False, False, False, False,
#          True]])

# %%
plt.figure(figsize=(15,8));
sns.heatmap(corr, annot=True, fmt='.2f', mask=mask);
plt.show()

# %%
# Находим пары признаков с корреляцией больше 0.6
CorField = []
for i in corr:
    for j in corr.index[corr[i] > 0.6]:
        if i != j and j not in CorField and i not in CorField:
            CorField.append(j)
            print (i, j, corr[i][corr.index == j].values[0])
# Out:
# NA_Sales EU_Sales 0.7653364809397203
# NA_Sales Other_Sales 0.6386538781708033
# NA_Sales Global_Sales 0.94101049425926

# %%
# Считаем корреляцию для 5 признаков
corr = df[['Global_Sales', 'Critic_Score', 'Critic_Count', 'User_Score', 'NA_Sales']].corr()  
corr
# Out:
#               Global_Sales  Critic_Score  Critic_Count  User_Score  NA_Sales
# Global_Sales      1.000000      0.245471      0.303571    0.088139  0.941010
# Critic_Score      0.245471      1.000000      0.425504    0.580878  0.240755
# Critic_Count      0.303571      0.425504      1.000000    0.194133  0.295413
# User_Score        0.088139      0.580878      0.194133    1.000000  0.086200
# NA_Sales          0.941010      0.240755      0.295413    0.086200  1.000000

# %% [markdown]
# https://en.wikipedia.org/wiki/Correlation_and_dependence

# %% [markdown]
# ! [Correlation_examples.png](attachment:Correlation_examples.png)

# %% [markdown]
# https://en.wikipedia.org/wiki/Distance_correlation

# %%
# Строим графики парных корреляций
sns.pairplot(df[['Global_Sales', 'Critic_Score', 'Critic_Count', 'User_Score', 'NA_Sales']]);
plt.show()

# %%
# Строим регрессионо-корреляционную прямую
sns.regplot(x="Global_Sales", y="NA_Sales", data=df)
plt.ylim(0,);
plt.show()

# %%
df[["Global_Sales", "NA_Sales"]].corr()
# Out:
#               Global_Sales  NA_Sales
# Global_Sales       1.00000   0.94101
# NA_Sales           0.94101   1.00000

# %%
df[["JP_Sales", "Year_of_Release"]].dtypes
# Out:
# JP_Sales           float64
# Year_of_Release      Int32
# dtype: object

# %%
sns.regplot(x="JP_Sales", y="Critic_Score", data=df);
plt.show()

# %%
df[["JP_Sales", "Critic_Score"]].dropna().corr()
# Out:
#               JP_Sales  Critic_Score
# JP_Sales      1.000000      0.152593
# Critic_Score  0.152593      1.000000

# %% [markdown]
# * boxplot

# %% [markdown]
# ![Densityvsbox.png](attachment:Densityvsbox.png)

# %% [markdown]
# ![440px-Boxplot_vs_PDF.svg.png](attachment:440px-Boxplot_vs_PDF.svg.png)

# %%
sns.boxplot(x=df['Critic_Score']);

# %%
df['Critic_Score'].hist();

# %%
sns.violinplot(x=df['Critic_Score'])
plt.show()

# %%
# Выберем топ платформ в датасете
top_platforms = df.Platform.value_counts().head(10)
top_platforms
# Out:
# Platform
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# Name: count, dtype: int64

# %%
# Нарисуем ящик с усами для топовых платформ
sns.boxplot(y="Platform", x="Critic_Score", data=df[df.Platform.isin(top_platforms.index.values)]);

# %%
plt.figure(figsize=(10,10));
sns.violinplot(y="Platform", x="Critic_Score", data=df[df.Platform.isin(top_platforms.index.values)]);

# %% [markdown]
# # Пропуски

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16719 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  Int32
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
df.isna().any()
# Out:
# Name               False
# Platform           False
# Year_of_Release     True
# Genre               True
# Publisher           True
# NA_Sales           False
# EU_Sales           False
# JP_Sales           False
# Other_Sales        False
# Global_Sales       False
# Critic_Score        True
# Critic_Count        True
# User_Score          True
# User_Count          True
# Developer           True
# Rating              True
# dtype: bool

# %%
df['Name'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16714    False
# 16715    False
# 16716    False
# 16717    False
# 16718    False
# Name: Name, Length: 16719, dtype: bool

# %%
df[df['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %%
df['Name'].fillna('Undefined', inplace=True)

# %%
df[df['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %%
df['Name'].isna().any()
# Out:
# False

# %%
df['Critic_Score'].median()
# Out:
# 71.0

# %%
df['Critic_Score']
# Out:
# 0        76.0
# 1         NaN
# 2        82.0
# 3        80.0
# 4         NaN
#          ...
# 16714     NaN
# 16715     NaN
# 16716     NaN
# 16717     NaN
# 16718     NaN
# Name: Critic_Score, Length: 16719, dtype: float64

# %%
df['Critic_Score'].fillna(df['Critic_Score'].median())
# Out:
# 0        76.0
# 1        71.0
# 2        82.0
# 3        80.0
# 4        71.0
#          ...
# 16714    71.0
# 16715    71.0
# 16716    71.0
# 16717    71.0
# 16718    71.0
# Name: Critic_Score, Length: 16719, dtype: float64

# %%
df['Critic_Score'].head(10)
# Out:
# 0    76.0
# 1     NaN
# 2    82.0
# 3    80.0
# 4     NaN
# 5     NaN
# 6    89.0
# 7    58.0
# 8    87.0
# 9     NaN
# Name: Critic_Score, dtype: float64

# %%
df['Critic_Score'].tail()
# Out:
# 16714   NaN
# 16715   NaN
# 16716   NaN
# 16717   NaN
# 16718   NaN
# Name: Critic_Score, dtype: float64

# %%
df['Critic_Score'].fillna(method='bfill').head(10)
# Out:
# 0    76.0
# 1    82.0
# 2    82.0
# 3    80.0
# 4    89.0
# 5    89.0
# 6    89.0
# 7    58.0
# 8    87.0
# 9    91.0
# Name: Critic_Score, dtype: float64

# %%
df['Critic_Score'].fillna(method='bfill').tail(10)
# Out:
# 16709    63.0
# 16710     NaN
# 16711     NaN
# 16712     NaN
# 16713     NaN
# 16714     NaN
# 16715     NaN
# 16716     NaN
# 16717     NaN
# 16718     NaN
# Name: Critic_Score, dtype: float64

# %%
df['Critic_Score'].fillna(method='ffill').head(10)
# Out:
# 0    76.0
# 1    76.0
# 2    82.0
# 3    80.0
# 4    80.0
# 5    80.0
# 6    89.0
# 7    58.0
# 8    87.0
# 9    87.0
# Name: Critic_Score, dtype: float64

# %% [markdown]
# # Изменение датафрейма

# %%
df['NA_EU_Sales'] = df['NA_Sales'] + df['EU_Sales']

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
df.drop('NA_EU_Sales', axis=1, inplace=True)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
df = df.drop('Sports', axis=1)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Продолжение анализа

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
df['Genre'].nunique()
# Out:
# 12

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       874
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: count, dtype: int64

# %%
df['Genre'].value_counts().sort_values(ascending=True)
# Out:
# Genre
# Puzzle           580
# Strategy         683
# Fighting         849
# Simulation       874
# Platform         888
# Racing          1249
# Adventure       1303
# Shooter         1323
# Role-Playing    1500
# Misc            1750
# Sports          2348
# Action          3370
# Name: count, dtype: int64

# %%
df['Genre'].value_counts().plot.bar();

# %%
df['Global_Sales'].mean()
# Out:
# 0.5335426759973684

# %%
df['Global_Sales'].max()
# Out:
# 82.53

# %%
df['Global_Sales'].min()
# Out:
# 0.01

# %%
df.rename(columns={'Name':'Game'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Game', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df.set_index('Game', inplace=True)

# %%
df.head()
# Out:
#                          Platform  Year_of_Release         Genre Publisher  \
# Game
# Wii Sports                    Wii             2006        Sports  Nintendo
# Super Mario Bros.             NES             1985      Platform  Nintendo
# Mario Kart Wii                Wii             2008        Racing  Nintendo
# Wii Sports Resort             Wii             2009        Sports  Nintendo
# Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Game
# Wii Sports                   41.36     28.96      3.77         8.45
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.68     12.76      3.79         3.29
# Wii Sports Resort            15.61     10.93      3.28         2.95
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales  Critic_Score  Critic_Count  \
# Game
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                        Game Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.rename(columns={'Game':'Name'}, inplace=True)

# %% [markdown]
# * группировка

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
sales_platform = df.groupby('Platform')['Global_Sales'].mean()

# %%
sales_platform
# Out:
# Platform
# 2600    0.729925
# 3DO     0.033333
# 3DS     0.498250
# DC      0.307115
# DS      0.375046
# GB      2.606633
# GBA     0.387470
# GC      0.358561
# GEN     1.061379
# GG      0.040000
# N64     0.686144
# NES     2.561939
# NG      0.120000
# PC      0.267248
# PCFX    0.030000
# PS      0.610426
# PS2     0.581046
# PS3     0.705808
# PS4     0.799567
# PSP     0.243424
# PSV     0.125278
# SAT     0.194162
# SCD     0.311667
# SNES    0.837029
# TG16    0.080000
# WS      0.236667
# Wii     0.687977
# WiiU    0.558912
# X360    0.769913
# XB      0.313422
# XOne    0.645506
# Name: Global_Sales, dtype: float64

# %%
sales_platform.sort_values(ascending=False).plot.bar();

# %%
sales_platform = df.groupby('Platform')['Global_Sales'].max()

# %%
sales_platform.nlargest(5)
# Out:
# Platform
# Wii     82.53
# NES     40.24
# GB      31.37
# DS      29.80
# X360    21.81
# Name: Global_Sales, dtype: float64

# %%
sales_platform_critic = df.groupby('Platform')[['Global_Sales', 'Critic_Score']].mean()

# %%
sales_platform_critic.sort_values('Critic_Score', ascending=False).head()
# Out:
#           Global_Sales  Critic_Score
# Platform
# DC            0.307115     87.357143
# PC            0.267248     75.928671
# XOne          0.645506     73.325444
# PS4           0.799567     72.091270
# PS            0.610426     71.515000

# %%
df.groupby(['Platform', 'Genre'])[['Global_Sales', 'Critic_Score']].mean()
# Out:
#                        Global_Sales  Critic_Score
# Platform Genre
# 2600     Action            0.480984           NaN
#          Adventure         0.850000           NaN
#          Fighting          0.620000           NaN
#          Misc              0.716000           NaN
#          Platform          1.474444           NaN
# ...                             ...           ...
# XOne     Role-Playing      0.753571     80.777778
#          Shooter           1.589211     77.656250
#          Simulation        0.172500     59.000000
#          Sports            0.704474     71.093750
#          Strategy          0.140000     70.000000
#
# [293 rows x 2 columns]

# %%
df.groupby(['Platform', 'Genre'])[['Critic_Score']].mean().unstack()
# Out:
#          Critic_Score                                                         \
# Genre          Action  Adventure   Fighting       Misc   Platform     Puzzle
# Platform
# 2600              NaN        NaN        NaN        NaN        NaN        NaN
# 3DO               NaN        NaN        NaN        NaN        NaN        NaN
# 3DS         63.118644  67.500000  68.857143  69.100000  72.444444  67.100000
# DC                NaN  88.000000  89.000000        NaN  89.000000        NaN
# DS          58.309353  61.372881  63.133333  63.322581  67.509091  66.722772
# GB                NaN        NaN        NaN        NaN        NaN        NaN
# GBA         62.152381  65.928571  67.250000  64.518519  68.074074  70.318182
# GC          67.747126  64.571429  69.962963  63.166667  63.813559  66.600000
# GEN               NaN        NaN        NaN        NaN        NaN        NaN
# GG                NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pivot = df.pivot_table(values='Critic_Score', index='Platform', columns='Genre', aggfunc='mean')

# %%
pivot
# Out:
# Genre        Action  Adventure   Fighting       Misc   Platform     Puzzle  \
# Platform
# 3DS       63.118644  67.500000  68.857143  69.100000  72.444444  67.100000
# DC              NaN  88.000000  89.000000        NaN  89.000000        NaN
# DS        58.309353  61.372881  63.133333  63.322581  67.509091  66.722772
# GBA       62.152381  65.928571  67.250000  64.518519  68.074074  70.318182
# GC        67.747126  64.571429  69.962963  63.166667  63.813559  66.600000
# PC        74.304965  71.875000  80.000000  73.200000  74.800000  81.500000
# PS        67.117647  58.000000  67.625000  73.833333  76.000000  81.000000
# PS2       66.725100  62.348837  70.063291  67.888889  66.410959  72.636364
# PS3       69.024896  68.300000  73.298246  71.960000  68.565217  75.000000
# PS4       72.107143  73.428571  72.636364  70.555556  71.727273  88.000000
# PSP       63.898876  63.461538  67.062500  66.034483  69.541667  65.538462
# ...

# %%
plt.figure(figsize=(15,8));
sns.heatmap(pivot, annot=True, fmt='.2f', cmap='Blues');
